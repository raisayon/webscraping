# %%
import numpy
import pandas
from bs4 import BeautifulSoup
import requests

# %%
#get methods from request
r = requests.get('https://www.bk.com/')

# %%
#checking connection
r.connection

# %%
#text from get method of request
html = r.text

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html lang="en">
#  <head>
#   <script>
#    // GTM boilerplate initialization --> Reference: https://developers.google.com/tag-manager/quickstart
#       function initializeGTM(w, d, s, l, i, b, e, p, k) {
#         // assign window.dataLayer
#         w[l] = w[l] || [];
#
#         // initial event for gtm tag initialization
#         w[l].push({ 'gtm.start': new Date().getTime(), event: 'gtm.js', environment: e, brand: b });
#         // create script for gtm
#         var f = d.getElementsByTagName(s)[0],
#           j = d.createElement(s),
#           dl = l != 'dataLayer' ? '&l=' + l : '';
#
#         j.async = true;
#         j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl + k;
#
#         // insert gtm script before other scripts
#         f.parentNode.insertBefore(j, f);
#
#         const startLoadTime = performance.now();
#         w.LOADING_START_TIME = startLoadTime;
# ...

# %%
#retrieve all meta tag
soup.find_all('meta')
# Out:
# [<meta charset="utf-8"/>,
#  <meta content="width=device-width,initial-scale=1,viewport-fit=cover,minimum-scale=1,maximum-scale=1" name="viewport"/>,
#  <meta content="Get access to exclusive coupons. Discover our menu and order delivery or pick up from a Burger King near you." name="description"/>,
#  <meta content="app-id=638323895" name="apple-itunes-app"/>,
#  <meta content="app-id=com.emn8.mobilem8.nativeapp.bk" name="google-play-app"/>,
#  <meta content="https://www.bk.com" property="og:url"/>,
#  <meta content="website" property="og:type"/>,
#  <meta content="Burger King: Online Offers and Ordering" property="og:title"/>,
#  <meta content="Get access to exclusive coupons. Discover our menu and order delivery or pick up from a Burger King near you." property="og:description"/>,
#  <meta content="https://cdn.sanity.io/images/czqk28jt/prod_bk/f4dc27eb7337f7cbd12d3ccd840e6a031fcba622-360x270.jpg" property="og:image"/>,
#  <meta content="#FFFFFF" name="theme-color"/>,
# ...
